# %%
# !pip install -q -U transformers accelerate bitsandbytes peft datasets safetensors sentencepiece evaluate huggingface_hub
# !pip install -q -U "transformers>=4.38.0" "datasets>=2.18.0" "peft>=0.9.0" "bitsandbytes>=0.41.0" "accelerate>=0.28.0" "safetensors" "sentencepiece" "evaluate" "huggingface_hub"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 96.8 MB/s eta 0:00:00:00:01:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.9/504.9 kB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 27.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.9/374.9 kB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.8/485.8 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 43.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.3 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.

# %%
# imports + device
import os
import math
import torch
from datasets import load_dataset
from transformers import (
    AutoTokenizer, AutoModelForCausalLM,
    TrainingArguments, Trainer, BitsAndBytesConfig
)
from peft import (
    LoraConfig, get_peft_model, prepare_model_for_kbit_training, PeftModel
)
from huggingface_hub import notebook_login
from tqdm.auto import tqdm
from huggingface_hub import login, HfFolder

print("Torch:", torch.__version__, " CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
HF_TOKEN = user_secrets.get_secret("HF_TOKEN")

login(token=HF_TOKEN) 
HfFolder.save_token(HF_TOKEN)
# Out:
# 2025-09-06 07:26:06.779573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757143567.155497      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757143567.269637      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Torch: 2.6.0+cu124  CUDA available: True
# GPU: Tesla T4

# %%
from huggingface_hub import HfApi
api = HfApi()

me = api.whoami(token=HF_TOKEN)
print("Token belongs to:", me.get("name") or me.get("user", {}).get("name") or me)

repo_id = "allout2726/type_summarized_git_diff_repo_deno"
try:
    info = api.model_info(repo_id, token=HF_TOKEN)
    print("Repo found. Files:", info.siblings)     
except Exception as e:
    print("Could not access repo:", e)
# Out:
# Token belongs to: allout2726
# Could not access repo: 404 Client Error. (Request ID: Root=1-68bbe221-66a9f46b6b1d3d2e3f4f3f74;5722fcb3-0a40-4250-8172-58940b9e948b)
#
# Repository Not Found for url: https://huggingface.co/api/models/allout2726/type_summarized_git_diff_repo_deno.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication

# %%
# Some globals
MODEL_NAME = "codellama/CodeLlama-7b-hf"
OUTPUT_DIR = "/kaggle/working/ccs_codellama7b_lora_summarised_deno"
DATASET_ID = "rsh-raj/deno-commits"
MAX_SEQ_LEN = 1024
PER_DEVICE_BATCH_SIZE = 1
NUM_EPOCHS =3
LEARNING_RATE = 3e-4
LORA_R = 8
LORA_ALPHA = 16
LORA_DROPOUT = 0.05
SEED = 42
torch.manual_seed(SEED)

# %%
#dataset
ds = load_dataset(DATASET_ID)

# ds["train"][0]
types_list_set = set()
for sample in ds["train"]:
    types_list_set.add(sample["type"])
types_list = list(types_list_set)
categories_str = ", ".join(sorted(types_list))
# Out:
# train.csv:   0%|          | 0.00/135M [00:00<?, ?B/s]
# val.csv: 0.00B [00:00, ?B/s]
# test.csv: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/1400 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/200 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400 [00:00<?, ? examples/s]

# %%
# Prompt template used for finetuning purpose and aslo for inferencing
PROMPT_HEAD = (
    f"<s>[INST] <<SYS>>\n"
    f"You are a commit classifier based on commit message and summary of the code diff."
    f"Please classify the given commit into one of the these categories: {{categories}}\n"
    f"<</SYS>>\n\n"
)
PROMPT_HEAD = PROMPT_HEAD.format(categories=categories_str)
PROMPT_COMMIT_MESSAGE = f"- given commit message:\n{{message}}\n"
PROMPT_COMMIT_SUMMARISED_DIFF = f"- given summary of the code diff: \n{{diff}}\n"

def applyTemplate(sample):
    return {
        "prompt_commit_message": PROMPT_COMMIT_MESSAGE.format(message=sample["masked_commit_message"]),
        "prompt_commit_summarised_diff": PROMPT_COMMIT_SUMMARISED_DIFF.format(diff=sample["summarized_git_diff"]),
        "response": f"[/INST] {sample['type']} </s>",
    }
print(PROMPT_HEAD[:400])
# def build_prompt(message, diff):
#     return PROMPT_HEAD + PROMPT_COMMIT_MESSAGE.format(message=message) + PROMPT_COMMIT_DIFF.format(diff=diff)
# temp = applyTemplate(ds["train"][0])
# print(tmp["prompt_commit_message"][:200])
# print("response:", tmp["response"])
# Out:
# <s>[INST] <<SYS>>
# You are a commit classifier based on commit message and summary of the code diff.Please classify the given commit into one of the these categories: breaking, build, chore, ci, doc, docs, feat, fix, perf, refactor, test, tests, upgrade
# <</SYS>>

# %%
# Map template i.e apply template to all the dataset
for i in ds.keys():
    ds[i] = ds[i].map(lambda x: applyTemplate(x))
print("Columns after template:", ds["train"].column_names)
# Out:
# Map:   0%|          | 0/1400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]
# Columns after template: ['hash', 'date', 'author', 'commit_message', 'is_merge', 'masked_commit_message', 'type', 'git_diff', 'summarized_git_diff', 'prompt_commit_message', 'prompt_commit_summarised_diff', 'response']

# %%
# Tokenizer load & adjustments
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=False, use_fast=False)
# ensure special tokens exist
if tokenizer.eos_token is None:
    tokenizer.add_special_tokens({"eos_token": "</s>"})
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
# Tokenization helper to add labels
def tokenize_add_label(sample, tokenizer=tokenizer, max_seq_len=MAX_SEQ_LEN):
    prompt_head_ids = tokenizer.encode(PROMPT_HEAD, add_special_tokens=False)
    message_ids = tokenizer.encode(sample["prompt_commit_message"], max_length=64, truncation=True, add_special_tokens=False)
    response_ids = tokenizer.encode(sample["response"], max_length=20, truncation=True, add_special_tokens=False)
    remaining = max_seq_len - (len(prompt_head_ids) + len(message_ids) + len(response_ids))
    if remaining < 0:
        message_ids = message_ids[:32]
        remaining = max_seq_len - (len(prompt_head_ids) + len(message_ids) + len(response_ids))
        if remaining < 0:
            response_ids = response_ids[:8]
            remaining = max_seq_len - (len(prompt_head_ids) + len(message_ids) + len(response_ids))
            remaining = max(0, remaining)
    diff_ids = tokenizer.encode(sample["prompt_commit_summarised_diff"], max_length=remaining, truncation=True, add_special_tokens=False)
    seq = prompt_head_ids + message_ids + diff_ids + response_ids
    pad_len = max_seq_len - len(seq)
    if pad_len > 0:
        seq += [tokenizer.eos_token_id] * pad_len
    attention_mask = [1]*max_seq_len
    labels = [-100] * (len(prompt_head_ids) + len(message_ids) + len(diff_ids)) + response_ids + [-100] * pad_len
    return {"input_ids": seq, "attention_mask": attention_mask, "labels": labels}

# Apply tokenization to all dataset
# for i in ds.keys():
for i in ds.keys():
    print("Tokenizing key:", i)
    ds[i] = ds[i].map(lambda x: tokenize_add_label(x), remove_columns=ds[i].column_names)
    ds[i].set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
print("Tokenization finished.")
ds["train"][0]
# Out:
# Tokenizing key: train
# Map:   0%|          | 0/1400 [00:00<?, ? examples/s]
# Tokenizing key: validation
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Tokenizing key: test
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]
# Tokenization finished.
# {'input_ids': tensor([    1, 29961, 25580,  ...,     2,     2,     2]),
#  'attention_mask': tensor([1, 1, 1,  ..., 1, 1, 1]),
#  'labels': tensor([-100, -100, -100,  ..., -100, -100, -100])}

# %%
# BitsAndBytes / quantization config + load model
from transformers import BitsAndBytesConfig

# bnb_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_quant_type="nf4",
#     bnb_4bit_use_double_quant=True,
#     bnb_4bit_compute_dtype=torch.float16
# )
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
    )

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=False,
    dtype=torch.float16
)

print("Model loaded.")
# Out:
# config.json:   0%|          | 0.00/637 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# {"timestamp":"2025-09-06T07:27:23.712187Z","level":"WARN","fields":{"message":"Status Code: 500. Retrying...","request_id":""},"filename":"/home/runner/work/xet-core/xet-core/cas_client/src/http_client.rs","line_number":236}
# {"timestamp":"2025-09-06T07:27:23.712302Z","level":"WARN","fields":{"message":"Retry attempt #0. Sleeping 1.456194266s before the next attempt"},"filename":"/root/.cargo/registry/src/index.crates.io-1949cf8c6b5b557f/reqwest-retry-0.7.0/src/middleware.rs","line_number":171}
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Model loaded.

# %%
# Prepare our model and apply LoRA (PEFT)
model = prepare_model_for_kbit_training(model)

target_modules = ["q_proj", "v_proj"]

peft_config = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    target_modules=target_modules,
    lora_dropout=LORA_DROPOUT,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, peft_config)

# %%
# Training arguments & trainer
from transformers import default_data_collator

training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=PER_DEVICE_BATCH_SIZE,
    per_device_eval_batch_size=PER_DEVICE_BATCH_SIZE,
    save_strategy="epoch",
    num_train_epochs=3,
    learning_rate=LEARNING_RATE,
    fp16=True,
    logging_strategy="steps",
    logging_steps=50,
    gradient_accumulation_steps=4,
    save_total_limit=2,
    remove_unused_columns=False,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds["train"],
    eval_dataset=ds["validation"],
    data_collator=default_data_collator
)
print("Trainer created.")
# Out:
# Trainer created.

# %%
# Finetune the model and save
trainer.train()
model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
repo_id="allout2726/type_summarized_git_diff_repo_deno"
model.push_to_hub(repo_id, use_auth_token=HF_TOKEN)
tokenizer.push_to_hub(repo_id, use_auth_token=HF_TOKEN)
print("Training finished and LoRA adapter saved to", OUTPUT_DIR)
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='1050' max='1050' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1050/1050 3:31:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.094700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.232200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.162000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.151100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.170100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.139900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.120600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.094400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.114100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.086500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.096000</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.103000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.108600</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.060200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.071700</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.037200</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.068000</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.041300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.048500</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.050200</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py:916: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...pt3v4a_lh/adapter_model.safetensors:   3%|3         |  563kB / 16.8MB
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   /tmp/tmph4s5mh5f/tokenizer.model      :  94%|#########3|  469kB /  500kB
# Training finished and LoRA adapter saved to /kaggle/working/ccs_codellama7b_lora_summarised_deno

# %%
# !pip install -q -U "transformers>=4.38.0" "datasets>=2.18.0" "peft>=0.9.0" "bitsandbytes>=0.41.0" "accelerate>=0.28.0" "safetensors" "sentencepiece" "evaluate" "huggingface_hub"
# import os
# import math
# import torch
# from datasets import load_dataset
# from transformers import (
#     AutoTokenizer, AutoModelForCausalLM,
#     TrainingArguments, Trainer, BitsAndBytesConfig
# )
# from peft import (
#     LoraConfig, get_peft_model, prepare_model_for_kbit_training, PeftModel
# )
# from huggingface_hub import notebook_login
# from tqdm.auto import tqdm
#inferencing the model on validation dataset
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16
)

# Load base again
base = AutoModelForCausalLM.from_pretrained(MODEL_NAME, quantization_config=bnb_config, device_map="auto", torch_dtype=torch.float16)
base = PeftModel.from_pretrained(base, OUTPUT_DIR, device_map="auto")  # load LoRA adapter
base.eval()
import re
# List of all possible types for classification
# TYPES_LIST = ["docs","perf","style","refactor","feat","fix","test","ci","build","chore"]
def build_prompt(message, diff):
    return PROMPT_HEAD + PROMPT_COMMIT_MESSAGE.format(message=message) + PROMPT_COMMIT_SUMMARISED_DIFF.format(diff=diff)

# def extractType(text):
#     lowered = text.lower()
#     for t in TYPES_LIST:
#         if (" " + t + " ") in (" " + lowered + " "):
#             return t
#     toks = lowered.replace("[/inst]","").replace("</s>","").strip().split()
#     for w in toks[:10]:
#         if w in TYPES_LIST:
#             return w
#     return None

def extractType(text):
    lowered = text.lower()

    matches = list(re.finditer(r'\[/inst\]', lowered, flags=re.IGNORECASE))
    if matches:
        tail = lowered[matches[-1].end():]  # substring after last [/INST]
    else:
        mid = max(0, len(lowered) // 2)
        tail = lowered[mid:]

    tail = re.split(r'<\/?s>', tail)[0]

    # Trim whitespace at edges
    tail = tail.strip()

    for t in types_list:
        if re.search(r'\b' + re.escape(t) + r'\b', tail):
            return t

    tokens = re.split(r'\s+', tail)[:8]
    for tok in tokens:
        cand = re.sub(r'[^a-zA-Z]', '', tok).lower()
        if cand in types_list:
            return cand

    for t in types_list:
        if re.search(r'\b' + re.escape(t) + r'\b', lowered):
            return t

    return None

# evaluate on validation
test_ds = load_dataset(DATASET_ID)["validation"]# right now inferencing on just 100 samples
correct = 0
total = 0
for sample in tqdm(test_ds):
    prompt = build_prompt(sample["masked_commit_message"], sample["summarized_git_diff"])
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=MAX_SEQ_LEN).to(base.device)
    with torch.no_grad():
        out = base.generate(**inputs, max_new_tokens=16, do_sample=False, temperature=0.0, eos_token_id=tokenizer.eos_token_id,pad_token_id=tokenizer.eos_token_id,)
    text_output=tokenizer.decode(out[0], skip_special_tokens=False)
    pred = extractType(text_output)
    actual_type = sample["type"].lower()
    # print(f"output :",text_output)
    print(f"pred: ",pred)
    print(f"actual: ",actual_type)

    if pred == actual_type:
        correct += 1
    total += 1

print(f"Test accuracy: {100*correct/total:.2f}% ({correct}/{total})")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  refactor
# pred:  feat
# actual:  feat
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  docs
# pred:  refactor
# actual:  refactor
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  fix
# pred:  refactor
# actual:  perf
# pred:  chore
# actual:  test
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  feat
# actual:  breaking
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  refactor
# pred:  feat
# actual:  feat
# pred:  upgrade
# actual:  upgrade
# pred:  chore
# actual:  ci
# pred:  refactor
# actual:  refactor
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  perf
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  chore
# pred:  chore
# actual:  fix
# pred:  feat
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  fix
# pred:  fix
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  refactor
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  perf
# actual:  perf
# pred:  chore
# actual:  chore
# pred:  refactor
# actual:  refactor
# pred:  refactor
# actual:  refactor
# pred:  refactor
# actual:  refactor
# pred:  breaking
# actual:  breaking
# pred:  docs
# actual:  docs
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  refactor
# actual:  refactor
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  feat
# actual:  chore
# pred:  refactor
# actual:  refactor
# pred:  chore
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  test
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  ci
# pred:  refactor
# actual:  refactor
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  feat
# pred:  fix
# actual:  chore
# pred:  refactor
# actual:  chore
# pred:  docs
# actual:  doc
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  perf
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  tests
# actual:  chore
# pred:  refactor
# actual:  fix
# pred:  feat
# actual:  perf
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  refactor
# pred:  fix
# actual:  chore
# pred:  refactor
# actual:  refactor
# pred:  chore
# actual:  chore
# pred:  feat
# actual:  feat
# pred:  feat
# actual:  feat
# pred:  ci
# actual:  ci
# pred:  refactor
# actual:  refactor
# pred:  chore
# actual:  upgrade
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  test
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  feat
# pred:  perf
# actual:  perf
# pred:  fix
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  refactor
# pred:  refactor
# actual:  refactor
# pred:  feat
# actual:  feat
# pred:  refactor
# actual:  refactor
# pred:  docs
# actual:  docs
# pred:  test
# actual:  test
# pred:  fix
# actual:  fix
# pred:  perf
# actual:  perf
# pred:  refactor
# actual:  chore
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  perf
# pred:  refactor
# actual:  refactor
# pred:  docs
# actual:  docs
# pred:  fix
# actual:  feat
# pred:  feat
# actual:  refactor
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  chore
# pred:  build
# actual:  build
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  docs
# actual:  docs
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  chore
# actual:  chore
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  perf
# pred:  chore
# actual:  feat
# pred:  chore
# actual:  chore
# pred:  build
# actual:  fix
# pred:  fix
# actual:  refactor
# pred:  feat
# actual:  fix
# pred:  docs
# actual:  docs
# pred:  feat
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  docs
# actual:  docs
# pred:  docs
# actual:  docs
# pred:  feat
# actual:  feat
# pred:  tests
# actual:  tests
# pred:  fix
# actual:  fix
# pred:  feat
# actual:  feat
# pred:  refactor
# actual:  refactor
# pred:  chore
# actual:  chore
# pred:  feat
# actual:  feat
# pred:  docs
# actual:  docs
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  refactor
# actual:  refactor
# pred:  feat
# actual:  feat
# pred:  chore
# actual:  chore
# pred:  feat
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  chore
# actual:  chore
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  feat
# pred:  refactor
# actual:  refactor
# pred:  refactor
# actual:  fix
# pred:  fix
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  perf
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  chore
# actual:  build
# pred:  refactor
# actual:  refactor
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  feat
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# pred:  fix
# actual:  fix
# Test accuracy: 75.00% (150/200)

# %%
# import os
import re
import torch
from tqdm.auto import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

repo_id = "allout2726/type_summarized_git_diff_repo_deno"  



login(HF_TOKEN)


# Load tokenizer from the Hub 
print("Loading tokenizer from:", repo_id)
tokenizer = AutoTokenizer.from_pretrained(repo_id, use_auth_token=HF_TOKEN)

# Load base model and then load the LoRA adapter from the Hub repo
print("Loading base model:", MODEL_NAME)
base = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
    dtype=torch.float16,
    use_auth_token=HF_TOKEN
)

print("Loading LoRA adapter from Hub repo:", repo_id)
base = PeftModel.from_pretrained(
    base,
    repo_id,
    device_map="auto",
    dtype=torch.float16,
    use_auth_token=HF_TOKEN
)

base.eval()
print("Model + adapter loaded. Device:", next(base.parameters()).device)

# helper to build prompt 
def build_prompt(message, diff):
    return PROMPT_HEAD + PROMPT_COMMIT_MESSAGE.format(message=message) + PROMPT_COMMIT_SUMMARISED_DIFF.format(diff=diff)

# TYPES_LIST = ["docs","perf","style","refactor","feat","fix","test","ci","build","chore"]

def extractType(text):
    lowered = text.lower()
    matches = list(re.finditer(r'\[/inst\]', lowered, flags=re.IGNORECASE))
    if matches:
        tail = lowered[matches[-1].end():]
    else:
        return None
        mid = max(0, len(lowered) // 2)
        tail = lowered[mid:]
    tail = re.split(r'<\/?s>', tail)[0].strip()
    for t in types_list:
        if re.search(r'\b' + re.escape(t) + r'\b', tail):
            return t
    tokens = re.split(r'\s+', tail)[:8]
    for tok in tokens:
        cand = re.sub(r'[^a-zA-Z]', '', tok).lower()
        if cand in types_list:
            return cand
    for t in types_list:
        if re.search(r'\b' + re.escape(t) + r'\b', lowered):
            return t
    return None

test_ds = load_dataset(DATASET_ID)["test"]
correct = 0
total = 0

for sample in tqdm(test_ds):
    prompt = build_prompt(sample["masked_commit_message"], sample["summarized_git_diff"])
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=MAX_SEQ_LEN).to(next(base.parameters()).device)
    with torch.no_grad():
        out = base.generate(
            **inputs,
            max_new_tokens=16,
            do_sample=False,
            temperature=0.0,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id,
        )
    text_output = tokenizer.decode(out[0], skip_special_tokens=False)
    # print(text_output)
    # print()
    pred = extractType(text_output)
    actual_type = sample["type"].lower()

    print("pred: ", pred)
    print("actual:", actual_type)

    if pred == actual_type:
        correct += 1
    total += 1

print(f"Test accuracy: {100*correct/total:.2f}% ({correct}/{total})")
# Out:
# Loading tokenizer from: allout2726/type_summarized_git_diff_repo_deno
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:1010: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# Loading base model: codellama/CodeLlama-7b-hf
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:492: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading LoRA adapter from Hub repo: allout2726/type_summarized_git_diff_repo_deno
# adapter_config.json:   0%|          | 0.00/859 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# Model + adapter loaded. Device: cuda:0
#   0%|          | 0/400 [00:00<?, ?it/s]
# pred:  build
# actual: fix
# pred:  docs
# actual: docs
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  docs
# actual: docs
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  feat
# actual: fix
# pred:  chore
# actual: chore
# pred:  feat
# actual: fix
# pred:  feat
# actual: perf
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  refactor
# actual: feat
# pred:  fix
# actual: chore
# pred:  chore
# actual: upgrade
# pred:  refactor
# actual: refactor
# pred:  refactor
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  ci
# actual: build
# pred:  fix
# actual: feat
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: docs
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: chore
# pred:  fix
# actual: refactor
# pred:  fix
# actual: perf
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  ci
# actual: ci
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  fix
# actual: refactor
# pred:  feat
# actual: feat
# pred:  breaking
# actual: chore
# pred:  refactor
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  None
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: feat
# pred:  fix
# actual: refactor
# pred:  feat
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: chore
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  docs
# actual: docs
# pred:  feat
# actual: fix
# pred:  fix
# actual: fix
# pred:  docs
# actual: chore
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  perf
# actual: perf
# pred:  feat
# actual: feat
# pred:  docs
# actual: doc
# pred:  fix
# actual: fix
# pred:  fix
# actual: test
# pred:  test
# actual: test
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: refactor
# pred:  feat
# actual: feat
# pred:  perf
# actual: perf
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  refactor
# actual: docs
# pred:  fix
# actual: fix
# pred:  fix
# actual: refactor
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  chore
# actual: refactor
# pred:  feat
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: refactor
# pred:  chore
# actual: ci
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: chore
# pred:  refactor
# actual: breaking
# pred:  chore
# actual: tests
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  docs
# actual: docs
# pred:  docs
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  chore
# actual: chore
# pred:  build
# actual: build
# pred:  perf
# actual: perf
# pred:  fix
# actual: fix
# pred:  chore
# actual: upgrade
# pred:  feat
# actual: feat
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: feat
# pred:  fix
# actual: feat
# pred:  fix
# actual: feat
# pred:  feat
# actual: feat
# pred:  feat
# actual: breaking
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: fix
# pred:  fix
# actual: fix
# pred:  docs
# actual: chore
# pred:  fix
# actual: fix
# pred:  refactor
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  feat
# actual: fix
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: chore
# pred:  feat
# actual: feat
# pred:  refactor
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  perf
# actual: perf
# pred:  fix
# actual: fix
# pred:  chore
# actual: upgrade
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  refactor
# actual: perf
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: chore
# pred:  perf
# actual: perf
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  refactor
# actual: breaking
# pred:  fix
# actual: tests
# pred:  refactor
# actual: refactor
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: test
# pred:  fix
# actual: refactor
# pred:  docs
# actual: docs
# pred:  fix
# actual: fix
# pred:  upgrade
# actual: upgrade
# pred:  docs
# actual: docs
# pred:  chore
# actual: chore
# pred:  feat
# actual: feat
# pred:  fix
# actual: perf
# pred:  fix
# actual: fix
# pred:  feat
# actual: refactor
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: chore
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: feat
# pred:  feat
# actual: feat
# pred:  fix
# actual: refactor
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  docs
# actual: docs
# pred:  fix
# actual: fix
# pred:  feat
# actual: test
# pred:  perf
# actual: perf
# pred:  feat
# actual: feat
# pred:  docs
# actual: docs
# pred:  feat
# actual: feat
# pred:  refactor
# actual: breaking
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: build
# pred:  fix
# actual: ci
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  docs
# actual: docs
# pred:  fix
# actual: test
# pred:  perf
# actual: perf
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  chore
# actual: docs
# pred:  fix
# actual: feat
# pred:  chore
# actual: test
# pred:  docs
# actual: docs
# pred:  feat
# actual: feat
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: fix
# pred:  fix
# actual: chore
# pred:  fix
# actual: feat
# pred:  feat
# actual: feat
# pred:  fix
# actual: chore
# pred:  refactor
# actual: chore
# pred:  refactor
# actual: fix
# pred:  refactor
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: feat
# pred:  docs
# actual: doc
# pred:  chore
# actual: chore
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: perf
# pred:  refactor
# actual: perf
# pred:  fix
# actual: fix
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: feat
# pred:  build
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: test
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  docs
# actual: chore
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  chore
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  refactor
# actual: fix
# pred:  fix
# actual: feat
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: build
# pred:  fix
# actual: perf
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  docs
# actual: docs
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  fix
# actual: feat
# pred:  chore
# actual: chore
# pred:  feat
# actual: chore
# pred:  chore
# actual: chore
# pred:  refactor
# actual: chore
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: fix
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  docs
# actual: chore
# pred:  feat
# actual: feat
# pred:  chore
# actual: chore
# pred:  docs
# actual: docs
# pred:  chore
# actual: test
# pred:  feat
# actual: feat
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: test
# pred:  chore
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  fix
# actual: perf
# pred:  fix
# actual: fix
# pred:  docs
# actual: fix
# pred:  chore
# actual: ci
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  feat
# actual: feat
# pred:  docs
# actual: docs
# pred:  feat
# actual: breaking
# pred:  feat
# actual: feat
# pred:  fix
# actual: feat
# pred:  refactor
# actual: refactor
# pred:  refactor
# actual: fix
# pred:  perf
# actual: chore
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  chore
# actual: chore
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  perf
# actual: perf
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  docs
# actual: docs
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  refactor
# actual: chore
# pred:  fix
# actual: feat
# pred:  fix
# actual: fix
# pred:  refactor
# actual: refactor
# pred:  fix
# actual: perf
# pred:  fix
# actual: fix
# pred:  feat
# actual: feat
# pred:  ci
# actual: ci
# pred:  feat
# actual: fix
# pred:  feat
# actual: feat
# pred:  chore
# actual: ci
# pred:  feat
# actual: feat
# pred:  chore
# actual: feat
# pred:  fix
# actual: perf
# pred:  feat
# actual: feat
# pred:  refactor
# actual: refactor
# pred:  chore
# actual: refactor
# pred:  fix
# actual: fix
# pred:  fix
# actual: fix
# pred:  feat
# actual: fix
# pred:  fix
# actual: feat
# pred:  refactor
# actual: refactor
# pred:  docs
# actual: fix
# pred:  refactor
# actual: refactor
# Test accuracy: 70.75% (283/400)

# %%
# !ls -la "/kaggle/working/ccs_codellama7b_lora"
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ls: cannot access '/kaggle/working/ccs_codellama7b_lora': No such file or directory
